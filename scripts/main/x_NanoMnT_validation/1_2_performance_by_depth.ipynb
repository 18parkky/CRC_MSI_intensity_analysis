# %%
import pysam 
import scanpy as sc
import numpy as np 
import pandas as pd
import seaborn as sns

# %%
PATH_BAM = '/node200data/18parkky/datasets/data/public/BAM/Kinker_et_al/Pool1_18.possorted_genome.bam'

bamfile = pysam.AlignmentFile(PATH_BAM, 'rb')

# %% [markdown]
# ## Create CB→Primary read count dictionary for each BAM

# %%
dict_CB_to_PrimaryReadCount = dict() 
for read in bamfile.fetch():
    if read.is_supplementary==True or read.is_secondary==True: continue 
    
    try:
        CB = read.get_tag('CB')
    except KeyError: continue 
    
    try:
        dict_CB_to_PrimaryReadCount[CB] += 1
    except KeyError:
        dict_CB_to_PrimaryReadCount[CB] = 1

# %%
PrimaryReadCount_distribution = list(dict_CB_to_PrimaryReadCount.values())
PrimaryReadCount_distribution_sampled = pd.Series(PrimaryReadCount_distribution).sample(10000)

# sns.histplot(x=PrimaryReadCount_distribution_sampled)

# %%
np.mean(PrimaryReadCount_distribution), np.std(PrimaryReadCount_distribution)
# Out:
# (291.8943223045676, 3588.1917506572795)

# %% [markdown]
# ## Estimate coverage

# %%
adata = sc.read_h5ad('/node200data/18parkky/datasets/data/public/processed_data/Kinker_et_al/CPM_data.metalabeled.h5ad')
sc.pp.calculate_qc_metrics(adata, inplace=True)

# %%
for k,v in dict_CB_to_PrimaryReadCount.items():
    print(k)
    break
# Out:
# ATAAGAGCACTACAGT-1

# %%
dict_CB_to_PrimaryReadCount2 = dict()
for k, v in dict_CB_to_PrimaryReadCount.items():
    dict_CB_to_PrimaryReadCount2[k.split('-')[0]] = v

# %%
adata_obs_pool18 = adata.obs[(adata.obs['PoolID']=='18')].copy()
adata_obs_pool18['str_CB'] = [ f"{CB.split('-')[0]}" for CB in adata_obs_pool18['CB']  ]
adata_obs_pool18[(adata_obs_pool18['str_CB'].isin(dict_CB_to_PrimaryReadCount2.keys()))]
# Out:
#                          CB                   CellLine PoolID     CancerType  \
# 0     AAACCTGAGACATAAC-1-18              NCIH2126_LUNG     18    Lung Cancer
# 1     AACGTTGTCACCCGAG-1-18              NCIH2126_LUNG     18    Lung Cancer
# 2     AACTGGTAGACACGAC-1-18              NCIH2126_LUNG     18    Lung Cancer
# 3     AACTGGTAGGGCTTGA-1-18              NCIH2126_LUNG     18    Lung Cancer
# 4     AACTGGTAGTACTTGC-1-18              NCIH2126_LUNG     18    Lung Cancer
# ...                     ...                        ...    ...            ...
# 4672  TTGCGTCGTACCGAGA-2-18  KPNSI9S_AUTONOMIC_GANGLIA     18  Neuroblastoma
# 4673  TTTATGCGTTCGCGAC-2-18  KPNSI9S_AUTONOMIC_GANGLIA     18  Neuroblastoma
# 4674  TTTGCGCCACTAGTAC-2-18  KPNSI9S_AUTONOMIC_GANGLIA     18  Neuroblastoma
# 4675  TTTGCGCGTCAACATC-2-18  KPNSI9S_AUTONOMIC_GANGLIA     18  Neuroblastoma
# 4676  TTTGTCAGTGCACTTA-2-18  KPNSI9S_AUTONOMIC_GANGLIA     18  Neuroblastoma
#
#       n_genes_by_counts  log1p_n_genes_by_counts   total_counts  \
# 0                  4318                 8.370779  990492.895983
# 1                  5200                 8.556606  991547.667782
# 2                  4004                 8.295299  990979.660870
# 3                  4295                 8.365440  992040.188205
# 4                  4842                 8.485290  989435.176133
# ...                 ...                      ...            ...
# 4672               3005                 8.008366  991380.986326
# 4673               2721                 7.909122  992743.210231
# 4674               3544                 8.173293  992555.831266
# 4675               3562                 8.178358  990567.216392
# 4676               3234                 8.081784  990582.356333
#
#       log1p_total_counts  pct_counts_in_top_50_genes  \
# 0              13.805959                   32.354608
# 1              13.807023                   29.400622
# 2              13.806450                   31.149621
# 3              13.807520                   36.316953
# 4              13.804891                   35.440173
# ...                  ...                         ...
# 4672           13.806855                   39.299255
# 4673           13.808228                   39.777086
# 4674           13.808040                   35.994898
# 4675           13.806034                   32.673267
# 4676           13.806049                   35.803906
#
#       pct_counts_in_top_100_genes  pct_counts_in_top_200_genes  \
# 0                       45.668343                    57.257208
# 1                       42.359627                    53.893044
# 2                       43.652357                    55.231719
# 3                       47.853220                    59.093503
# 4                       46.069994                    56.116530
# ...                           ...                          ...
# 4672                    55.249052                    65.008498
# 4673                    56.618658                    66.555692
# 4674                    51.765306                    62.219388
# 4675                    46.421139                    56.776187
# 4676                    52.173069                    62.320528
#
#       pct_counts_in_top_500_genes            str_CB
# 0                       70.751576  AAACCTGAGACATAAC
# 1                       68.073635  AACGTTGTCACCCGAG
# 2                       69.585576  AACTGGTAGACACGAC
# 3                       72.016975  AACTGGTAGGGCTTGA
# 4                       69.293045  AACTGGTAGTACTTGC
# ...                           ...               ...
# 4672                    76.696300  TTGCGTCGTACCGAGA
# 4673                    77.701382  TTTATGCGTTCGCGAC
# 4674                    74.071429  TTTGCGCCACTAGTAC
# 4675                    69.414139  TTTGCGCGTCAACATC
# 4676                    74.058983  TTTGTCAGTGCACTTA
#
# [4677 rows x 13 columns]

# %%
adata_j = sc.read_h5ad('/node200data/18parkky/datasets/data/public/processed_data/Joanito_et_al/2_cell_type_labeled_h5ad/Joanito.preprocessed.NanoMnT.ManualAnnot.Epi.h5ad')
adata_j.obs
# Out:
#                     doublet_score  predicted_doublet SampleID PatientID  \
# AAACGGGTCGAGGTAG-1       0.054222              False   XHC078   CRC2783
# AAAGCAAAGATCACGG-1       0.031230              False   XHC078   CRC2783
# AACCATGCAGCCTGTG-1       0.034114              False   XHC078   CRC2783
# AACCATGGTCAATACC-1       0.026209              False   XHC078   CRC2783
# AACCGCGAGGCGCTCT-1       0.034114              False   XHC078   CRC2783
# ...                           ...                ...      ...       ...
# TGTGTTTCAGCTGCAC-1       0.048679              False   EXT115     SC041
# TTCTCCTGTTGTTTGG-1       0.052786              False   EXT115     SC041
# TTGACTTAGGAATTAC-1       0.074906              False   EXT115     SC041
# TTGGCAAAGGACACCA-1       0.057364              False   EXT115     SC041
# TTTGGTTGTCTGCCAG-1       0.062500              False   EXT115     SC041
#
#                                 BiopsySite  n_genes_by_counts  \
# AAACGGGTCGAGGTAG-1                    Core               5290
# AAAGCAAAGATCACGG-1                    Core               3378
# AACCATGCAGCCTGTG-1                    Core               4212
# AACCATGGTCAATACC-1                    Core               4628
# AACCGCGAGGCGCTCT-1                    Core               5206
# ...                                    ...                ...
# TGTGTTTCAGCTGCAC-1  Adjacent normal tissue               2758
# TTCTCCTGTTGTTTGG-1  Adjacent normal tissue               5423
# TTGACTTAGGAATTAC-1  Adjacent normal tissue               3597
# TTGGCAAAGGACACCA-1  Adjacent normal tissue               4368
# TTTGGTTGTCTGCCAG-1  Adjacent normal tissue               4245
#
#                     log1p_n_genes_by_counts  total_counts  log1p_total_counts  \
# AAACGGGTCGAGGTAG-1                 8.573763       25282.0           10.137888
# AAAGCAAAGATCACGG-1                 8.125335       11074.0            9.312446
# AACCATGCAGCCTGTG-1                 8.345930       11043.0            9.309643
# AACCATGGTCAATACC-1                 8.440096       18315.0            9.815531
# AACCGCGAGGCGCTCT-1                 8.557759       40752.0           10.615285
# ...                                     ...           ...                 ...
# TGTGTTTCAGCTGCAC-1                 7.922624        8870.0            9.090543
# TTCTCCTGTTGTTTGG-1                 8.598589       25402.0           10.142623
# TTGACTTAGGAATTAC-1                 8.188133       20543.0            9.930325
# TTGGCAAAGGACACCA-1                 8.382289       17133.0            9.748820
# TTTGGTTGTCTGCCAG-1                 8.353733       17426.0            9.765776
#
#                     pct_counts_in_top_50_genes  ...  Author_CellType_lvl_1  \
# AAACGGGTCGAGGTAG-1                   28.506447  ...             Epithelial
# AAAGCAAAGATCACGG-1                   38.468485  ...             Epithelial
# AACCATGCAGCCTGTG-1                   26.070814  ...             Epithelial
# AACCATGGTCAATACC-1                   32.825553  ...             Epithelial
# AACCGCGAGGCGCTCT-1                   45.062819  ...             Epithelial
# ...                                        ...  ...                    ...
# TGTGTTTCAGCTGCAC-1                   34.385569  ...             Epithelial
# TTCTCCTGTTGTTTGG-1                   29.690576  ...             Epithelial
# TTGACTTAGGAATTAC-1                   52.007983  ...             Epithelial
# TTGGCAAAGGACACCA-1                   31.687387  ...             Epithelial
# TTTGGTTGTCTGCCAG-1                   38.769655  ...             Epithelial
#
#                     Author_CellType_lvl_2  n_genes  leiden  AvgSTRDiff  \
# AAACGGGTCGAGGTAG-1                    N/A     5290       6   -2.084337
# AAAGCAAAGATCACGG-1                    N/A     3378       6   -1.884615
# AACCATGCAGCCTGTG-1                    N/A     4212       6   -1.968085
# AACCATGGTCAATACC-1                    N/A     4628       6   -1.618421
# AACCGCGAGGCGCTCT-1                    N/A     5206       6   -1.963415
# ...                                   ...      ...     ...         ...
# TGTGTTTCAGCTGCAC-1                    N/A     2758       3    0.255814
# TTCTCCTGTTGTTTGG-1                    N/A     5423       3    0.091954
# TTGACTTAGGAATTAC-1                    N/A     3597       3   -0.250000
# TTGGCAAAGGACACCA-1                    N/A     4368       3   -0.772727
# TTTGGTTGTCTGCCAG-1                    N/A     4245       3   -0.127660
#
#                     StdSTRDiff NumSTRLoci    MSI BiopsySite2  \
# AAACGGGTCGAGGTAG-1    2.612319         83  MSI-H       Tumor
# AAAGCAAAGATCACGG-1    2.334143         52  MSI-H       Tumor
# AACCATGCAGCCTGTG-1    2.528359         94  MSI-H       Tumor
# AACCATGGTCAATACC-1    1.953183         76  MSI-H       Tumor
# AACCGCGAGGCGCTCT-1    2.126747         82  MSI-H       Tumor
# ...                        ...        ...    ...         ...
# TGTGTTTCAGCTGCAC-1    1.221761         43    MSS      Normal
# TTCTCCTGTTGTTTGG-1    1.228326         87    MSS      Normal
# TTGACTTAGGAATTAC-1    1.944544         64    MSS      Normal
# TTGGCAAAGGACACCA-1    2.472855         66    MSS      Normal
# TTTGGTTGTCTGCCAG-1    1.330766         47    MSS      Normal
#
#                     Manual_CellType_lvl_1
# AAACGGGTCGAGGTAG-1       Tumor epithelial
# AAAGCAAAGATCACGG-1       Tumor epithelial
# AACCATGCAGCCTGTG-1       Tumor epithelial
# AACCATGGTCAATACC-1       Tumor epithelial
# AACCGCGAGGCGCTCT-1       Tumor epithelial
# ...                                   ...
# TGTGTTTCAGCTGCAC-1      Normal epithelial
# TTCTCCTGTTGTTTGG-1      Normal epithelial
# TTGACTTAGGAATTAC-1      Normal epithelial
# TTGGCAAAGGACACCA-1      Normal epithelial
# TTTGGTTGTCTGCCAG-1      Normal epithelial
#
# [8240 rows x 27 columns]

# %%
np.mean(adata.obs['total_counts'])/np.mean(adata_j.obs['total_counts'])
# Out:
# 39.02190609962194
